# %%
# %matplotlib inline

# %%
import pandas as pd
import os
from functools import reduce
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats.stats import pearsonr
from scipy import stats
from scipy.stats import ks_2samp
from scipy.stats import entropy

# %% [markdown]
# ## Datafiles
# There are 96 separate datafiles, each representing the processed output of an RNAseq experiment looking at mRNA levels in wild-type (48 samples) or SNF2 deletion (48 samples) yeast cells grown under standard condition.

# %% [markdown]
# ## Reading individual files with Pandas
#
# The individual files are in the directory "data/rawdata/" and are tab-delimeted text files. These are basically raw spreadsheets stored as text, with individual lines separated by a **'\n'** which indicated 'new line', and columns within each line separated by a **'\t'** or 'tab' character. (We will also deal with files where the column is separated by a comma.

# %% [markdown]
# Like any good program for working with spreadsheet data, Pandas knows how to read this kind of file if we tell it what to look for. To do this we use its [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) function, specifying first the filepath, and then a few details about this file.
#
# **sep="\t"** tells Pandas that the data separator is a tab character (as opposed to other common separators like comma or space)
# **header=None** tells Pandas that the first line of the file is not a header (this is what it typically expects)
# **names = ..** because there is no header, we tell Pandas what to call the columns

# %%
pd.read_csv("data/rawdata/WT_rep16_MID92_allLanes_tophat2.0.5.bam.gbgout",sep="\t",header=None,names=["Gene","Expression"])
# Out:
#                       Gene  Expression
# 0                 15S_rRNA          29
# 1                 21S_rRNA         221
# 2                     HRA1           0
# 3                     ICR1          70
# 4                     LSR1         314
# ...                    ...         ...
# 7126            no_feature      414503
# 7127             ambiguous     1387186
# 7128         too_low_aQual           0
# 7129           not_aligned           0
# 7130  alignment_not_unique           0
#
# [7131 rows x 2 columns]

# %% [markdown]
# If we just run that command, Pandas loads in the file and displays it. But we want to store the data, so we assign the data to a variable.

# %%
ge = pd.read_csv("data/rawdata/WT_rep16_MID92_allLanes_tophat2.0.5.bam.gbgout",sep="\t",header=None,names=["Gene","Expression"])

# %% [markdown]
# Now we can look at the file in different ways. The **head(n)** command shows us the first n rows.

# %%
ge.head(10)
# Out:
#        Gene  Expression
# 0  15S_rRNA          29
# 1  21S_rRNA         221
# 2      HRA1           0
# 3      ICR1          70
# 4      LSR1         314
# 5      NME1          33
# 6      PWR1           0
# 7     Q0010           0
# 8     Q0017           0
# 9     Q0032           0

# %% [markdown]
# Similarly the **tail(n)** command shows us the last n rows.

# %%
ge.tail(10)
# Out:
#                       Gene  Expression
# 7121             tY(GUA)J2           0
# 7122             tY(GUA)M1           0
# 7123             tY(GUA)M2           0
# 7124              tY(GUA)O           0
# 7125              tY(GUA)Q           0
# 7126            no_feature      414503
# 7127             ambiguous     1387186
# 7128         too_low_aQual           0
# 7129           not_aligned           0
# 7130  alignment_not_unique           0

# %% [markdown]
# You can already see one (typical) problem, which is that the file is not just data. It also how some summary statistics that we don't care about. So we have to filter the rows in some manner. Here we use a bit of data about gene nomenclature in yeast.
#
# Most of the genes have this naming format:
#
# Systematic names for nuclear-encoded ORFs begin with the letter 'Y' (for 'Yeast'); the second letter denotes the chromosome number ('A' is chr I, 'B' is chr II, etc.); the third letter is either 'L' or 'R' for left or right chromosome arm; next is a three digit number indicating the order of the ORFs on that arm of a chromosome starting from the centromere, irrespective of strand; finally, there is an additional letter indicating the strand, either 'W' for Watson (the strand with 5' end at the left telomere) or 'C' for Crick (the complement strand, 5' end is at the right telomere).
#
# You can read about the yeast gene naming system here - http://seq.yeastgenome.org/help/community/nomenclature-conventions.

# %% [markdown]
# We can look for rows that match this style by using the built in filtering system in Pandas. This specific command asks Pandas to return all rows where the Gene column starts with the character "Y"

# %%
ge[ge.Gene.str.startswith("Y")]
# Out:
#            Gene  Expression
# 61      YAL001C         232
# 62      YAL002W         245
# 63      YAL003W        8073
# 64      YAL004W           0
# 65      YAL005C        7471
# ...         ...         ...
# 6741    YPR201W          45
# 6742    YPR202W          22
# 6743    YPR203W          18
# 6744  YPR204C-A           0
# 6745    YPR204W         633
#
# [6685 rows x 2 columns]

# %% [markdown]
# That accounts for 6685 of the 7130 rows. But what about the rest? We can start by reversing that filter to ask for rows that do not start with "Y". That work is done here with the **~** symbol.

# %%
ge[~ge.Gene.str.startswith("Y")]
# Out:
#                       Gene  Expression
# 0                 15S_rRNA          29
# 1                 21S_rRNA         221
# 2                     HRA1           0
# 3                     ICR1          70
# 4                     LSR1         314
# ...                    ...         ...
# 7126            no_feature      414503
# 7127             ambiguous     1387186
# 7128         too_low_aQual           0
# 7129           not_aligned           0
# 7130  alignment_not_unique           0
#
# [446 rows x 2 columns]

# %% [markdown]
# This is going to look a bit messy, but we can ask Pandas to return all of the Gene names for these remaining rows, just so we can get a sense of what we're dealing with.

# %%
ge[~ge.Gene.str.startswith("Y")].Gene.values
# Out:
# array(['15S_rRNA', '21S_rRNA', 'HRA1', 'ICR1', 'LSR1', 'NME1', 'PWR1',
#        'Q0010', 'Q0017', 'Q0032', 'Q0045', 'Q0050', 'Q0055', 'Q0060',
#        'Q0065', 'Q0070', 'Q0075', 'Q0080', 'Q0085', 'Q0092', 'Q0105',
#        'Q0110', 'Q0115', 'Q0120', 'Q0130', 'Q0140', 'Q0142', 'Q0143',
#        'Q0144', 'Q0160', 'Q0182', 'Q0250', 'Q0255', 'Q0275', 'Q0297',
#        'RDN18-1', 'RDN18-2', 'RDN25-1', 'RDN25-2', 'RDN37-1', 'RDN37-2',
#        'RDN5-1', 'RDN5-2', 'RDN5-3', 'RDN5-4', 'RDN5-5', 'RDN5-6',
#        'RDN58-1', 'RDN58-2', 'RNA170', 'RPM1', 'RPR1', 'RUF20', 'RUF21',
#        'RUF22', 'RUF23', 'RUF5-1', 'RUF5-2', 'SCR1', 'SRG1', 'TLC1',
#        'snR10', 'snR11', 'snR128', 'snR13', 'snR14', 'snR161', 'snR17a',
#        'snR17b', 'snR18', 'snR189', 'snR19', 'snR190', 'snR191', 'snR24',
#        'snR3', 'snR30', 'snR31', 'snR32', 'snR33', 'snR34', 'snR35',
#        'snR36', 'snR37', 'snR38', 'snR39', 'snR39B', 'snR4', 'snR40',
#        'snR41', 'snR42', 'snR43', 'snR44', 'snR45', 'snR46', 'snR47',
#        'snR48', 'snR49', 'snR5', 'snR50', 'snR51', 'snR52', 'snR53',
#        'snR54', 'snR55', 'snR56', 'snR57', 'snR58', 'snR59', 'snR6',
#        'snR60', 'snR61', 'snR62', 'snR63', 'snR64', 'snR65', 'snR66',
#        'snR67', 'snR68', 'snR69', 'snR7-L', 'snR7-S', 'snR70', 'snR71',
#        'snR72', 'snR73', 'snR74', 'snR75', 'snR76', 'snR77', 'snR78',
#        'snR79', 'snR8', 'snR80', 'snR81', 'snR82', 'snR83', 'snR84',
#        'snR85', 'snR86', 'snR87', 'snR9', 'tA(AGC)D', 'tA(AGC)F',
#        'tA(AGC)G', 'tA(AGC)H', 'tA(AGC)J', 'tA(AGC)K1', 'tA(AGC)K2',
#        'tA(AGC)L', 'tA(AGC)M1', 'tA(AGC)M2', 'tA(AGC)P', 'tA(UGC)A',
#        'tA(UGC)E', 'tA(UGC)G', 'tA(UGC)L', 'tA(UGC)O', 'tA(UGC)Q',
#        'tC(GCA)B', 'tC(GCA)G', 'tC(GCA)P1', 'tC(GCA)P2', 'tC(GCA)Q',
#        'tD(GUC)B', 'tD(GUC)D', 'tD(GUC)G1', 'tD(GUC)G2', 'tD(GUC)I1',
#        'tD(GUC)I2', 'tD(GUC)J1', 'tD(GUC)J2', 'tD(GUC)J3', 'tD(GUC)J4',
#        'tD(GUC)K', 'tD(GUC)L1', 'tD(GUC)L2', 'tD(GUC)M', 'tD(GUC)N',
#        'tD(GUC)O', 'tD(GUC)Q', 'tE(CUC)D', 'tE(CUC)I', 'tE(UUC)B',
#        'tE(UUC)C', 'tE(UUC)E1', 'tE(UUC)E2', 'tE(UUC)E3', 'tE(UUC)G1',
#        'tE(UUC)G2', 'tE(UUC)G3', 'tE(UUC)I', 'tE(UUC)J', 'tE(UUC)K',
#        'tE(UUC)L', 'tE(UUC)M', 'tE(UUC)P', 'tE(UUC)Q', 'tF(GAA)B',
#        'tF(GAA)D', 'tF(GAA)F', 'tF(GAA)G', 'tF(GAA)H1', 'tF(GAA)H2',
#        'tF(GAA)M', 'tF(GAA)N', 'tF(GAA)P1', 'tF(GAA)P2', 'tF(GAA)Q',
#        'tG(CCC)D', 'tG(CCC)O', 'tG(GCC)B', 'tG(GCC)C', 'tG(GCC)D1',
#        'tG(GCC)D2', 'tG(GCC)E', 'tG(GCC)F1', 'tG(GCC)F2', 'tG(GCC)G1',
#        'tG(GCC)G2', 'tG(GCC)J1', 'tG(GCC)J2', 'tG(GCC)M', 'tG(GCC)O1',
#        'tG(GCC)O2', 'tG(GCC)P1', 'tG(GCC)P2', 'tG(UCC)G', 'tG(UCC)N',
#        'tG(UCC)O', 'tG(UCC)Q', 'tH(GUG)E1', 'tH(GUG)E2', 'tH(GUG)G1',
#        'tH(GUG)G2', 'tH(GUG)H', 'tH(GUG)K', 'tH(GUG)M', 'tH(GUG)Q',
#        'tI(AAU)B', 'tI(AAU)D', 'tI(AAU)E1', 'tI(AAU)E2', 'tI(AAU)G',
#        'tI(AAU)I1', 'tI(AAU)I2', 'tI(AAU)L1', 'tI(AAU)L2', 'tI(AAU)N1',
#        'tI(AAU)N2', 'tI(AAU)P1', 'tI(AAU)P2', 'tI(GAU)Q', 'tI(UAU)D',
#        'tI(UAU)L', 'tK(CUU)C', 'tK(CUU)D1', 'tK(CUU)D2', 'tK(CUU)E1',
#        'tK(CUU)E2', 'tK(CUU)F', 'tK(CUU)G1', 'tK(CUU)G2', 'tK(CUU)G3',
#        'tK(CUU)I', 'tK(CUU)J', 'tK(CUU)K', 'tK(CUU)M', 'tK(CUU)P',
#        'tK(UUU)D', 'tK(UUU)G1', 'tK(UUU)G2', 'tK(UUU)K', 'tK(UUU)L',
#        'tK(UUU)O', 'tK(UUU)P', 'tK(UUU)Q', 'tL(CAA)A', 'tL(CAA)C',
#        'tL(CAA)D', 'tL(CAA)G1', 'tL(CAA)G2', 'tL(CAA)G3', 'tL(CAA)K',
#        'tL(CAA)L', 'tL(CAA)M', 'tL(CAA)N', 'tL(GAG)G', 'tL(UAA)B1',
#        'tL(UAA)B2', 'tL(UAA)D', 'tL(UAA)J', 'tL(UAA)K', 'tL(UAA)L',
#        'tL(UAA)N', 'tL(UAA)Q', 'tL(UAG)J', 'tL(UAG)L1', 'tL(UAG)L2',
#        'tM(CAU)C', 'tM(CAU)D', 'tM(CAU)E', 'tM(CAU)J1', 'tM(CAU)J2',
#        'tM(CAU)J3', 'tM(CAU)M', 'tM(CAU)O1', 'tM(CAU)O2', 'tM(CAU)P',
#        'tM(CAU)Q1', 'tM(CAU)Q2', 'tN(GUU)C', 'tN(GUU)F', 'tN(GUU)G',
#        'tN(GUU)K', 'tN(GUU)L', 'tN(GUU)N1', 'tN(GUU)N2', 'tN(GUU)O1',
#        'tN(GUU)O2', 'tN(GUU)P', 'tN(GUU)Q', 'tP(AGG)C', 'tP(AGG)N',
#        'tP(UGG)A', 'tP(UGG)F', 'tP(UGG)H', 'tP(UGG)L', 'tP(UGG)M',
#        'tP(UGG)N1', 'tP(UGG)N2', 'tP(UGG)O1', 'tP(UGG)O2', 'tP(UGG)O3',
#        'tP(UGG)Q', 'tQ(CUG)M', 'tQ(UUG)B', 'tQ(UUG)C', 'tQ(UUG)D1',
#        'tQ(UUG)D2', 'tQ(UUG)D3', 'tQ(UUG)E1', 'tQ(UUG)E2', 'tQ(UUG)H',
#        'tQ(UUG)L', 'tQ(UUG)Q', 'tR(ACG)D', 'tR(ACG)E', 'tR(ACG)J',
#        'tR(ACG)K', 'tR(ACG)L', 'tR(ACG)O', 'tR(ACG)Q2', 'tR(CCG)L',
#        'tR(CCU)J', 'tR(UCU)B', 'tR(UCU)D', 'tR(UCU)E', 'tR(UCU)G1',
#        'tR(UCU)G2', 'tR(UCU)G3', 'tR(UCU)J1', 'tR(UCU)J2', 'tR(UCU)K',
#        'tR(UCU)M1', 'tR(UCU)M2', 'tR(UCU)Q1', 'tS(AGA)A', 'tS(AGA)B',
#        'tS(AGA)D1', 'tS(AGA)D2', 'tS(AGA)D3', 'tS(AGA)E', 'tS(AGA)G',
#        'tS(AGA)H', 'tS(AGA)J', 'tS(AGA)L', 'tS(AGA)M', 'tS(CGA)C',
#        'tS(GCU)F', 'tS(GCU)L', 'tS(GCU)O', 'tS(GCU)Q1', 'tS(UGA)E',
#        'tS(UGA)I', 'tS(UGA)P', 'tS(UGA)Q2', 'tT(AGU)B', 'tT(AGU)C',
#        'tT(AGU)D', 'tT(AGU)H', 'tT(AGU)I1', 'tT(AGU)I2', 'tT(AGU)J',
#        'tT(AGU)N1', 'tT(AGU)N2', 'tT(AGU)O1', 'tT(AGU)O2', 'tT(CGU)K',
#        'tT(UGU)G1', 'tT(UGU)G2', 'tT(UGU)H', 'tT(UGU)P', 'tT(UGU)Q1',
#        'tT(XXX)Q2', 'tV(AAC)E1', 'tV(AAC)E2', 'tV(AAC)G1', 'tV(AAC)G2',
#        'tV(AAC)G3', 'tV(AAC)H', 'tV(AAC)J', 'tV(AAC)K1', 'tV(AAC)K2',
#        'tV(AAC)L', 'tV(AAC)M1', 'tV(AAC)M2', 'tV(AAC)M3', 'tV(AAC)O',
#        'tV(CAC)D', 'tV(CAC)H', 'tV(UAC)B', 'tV(UAC)D', 'tV(UAC)Q',
#        'tW(CCA)G1', 'tW(CCA)G2', 'tW(CCA)J', 'tW(CCA)K', 'tW(CCA)M',
#        'tW(CCA)P', 'tW(UCA)Q', 'tX(XXX)D', 'tY(GUA)D', 'tY(GUA)F1',
#        'tY(GUA)F2', 'tY(GUA)J1', 'tY(GUA)J2', 'tY(GUA)M1', 'tY(GUA)M2',
#        'tY(GUA)O', 'tY(GUA)Q', 'no_feature', 'ambiguous', 'too_low_aQual',
#        'not_aligned', 'alignment_not_unique'], dtype=object)

# %% [markdown]
# There are several types of things in here.
#
# **ribosomal RNAs** '15S_rRNA', '21S_rRNA'
# **non-coding RNAs** 'HRA1', 'ICR1', 'LSR1', 'NME1', 'PWR1', etc..
# **dubious open-reading frames** 'Q0010', 'Q0017', 'Q0032', 'Q0045', etc...
# **snoRNAs** snR10', 'snR11', 'snR128', 'snR13', 'snR14', 'snR161', 'snR17a', etc...
# **tRNAs** 'tA(AGC)D', 'tA(AGC)F','tA(AGC)G', 'tA(AGC)H', 'tA(AGC)J', 'tA(AGC)K1', etc...
# **summary rows - not genes** 'no_feature', 'ambiguous', 'too_low_aQual','not_aligned', 'alignment_not_unique'

# %% [markdown]
# For many subsequent analyses, we'll stick to protein-coding genes. But for now, lets just get rid of the superfluous stuff.

# %%
rows_to_drop = ['no_feature', 'ambiguous', 'too_low_aQual','not_aligned', 'alignment_not_unique']

# %%
ge = ge[~ge.Gene.isin(rows_to_drop)]

# %%
ge.head(10)
# Out:
#        Gene  Expression
# 0  15S_rRNA          29
# 1  21S_rRNA         221
# 2      HRA1           0
# 3      ICR1          70
# 4      LSR1         314
# 5      NME1          33
# 6      PWR1           0
# 7     Q0010           0
# 8     Q0017           0
# 9     Q0032           0

# %% [markdown]
# So, we've got 96 files like this. For what we want to do, we want to combine these all into one giant table. Fortunately, pandas has a relative easy way to merge dataframes.

# %% [markdown]
# To illustrate this, first lets load two:

# %%
ge1 = pd.read_csv("data/rawdata/WT_rep16_MID92_allLanes_tophat2.0.5.bam.gbgout",sep="\t",header=None,names=["Gene","Expression"])
ge1 = ge1[~ge1.Gene.isin(rows_to_drop)]
ge2 = pd.read_csv("data/rawdata/Snf2_rep03_MID28_allLanes_tophat2.0.5.bam.gbgout",sep="\t",header=None,names=["Gene","Expression"])
ge2 = ge2[~ge2.Gene.isin(rows_to_drop)]

# %%
ge1.head(10)
# Out:
#        Gene  Expression
# 0  15S_rRNA          29
# 1  21S_rRNA         221
# 2      HRA1           0
# 3      ICR1          70
# 4      LSR1         314
# 5      NME1          33
# 6      PWR1           0
# 7     Q0010           0
# 8     Q0017           0
# 9     Q0032           0

# %%
ge2.head(10)
# Out:
#        Gene  Expression
# 0  15S_rRNA           5
# 1  21S_rRNA          23
# 2      HRA1           3
# 3      ICR1         211
# 4      LSR1         159
# 5      NME1          17
# 6      PWR1           0
# 7     Q0010           0
# 8     Q0017           0
# 9     Q0032           0

# %% [markdown]
# The merge syntax for merging two dataframes df1, df2 is pretty easy
#
# **df1.merge(df2,on="Gene",how="outer")**
#
# In addition to the two dataframes, you have to specify what column of the dataframes you want to merge on. When pandas finds the same value in this column between two dataframes, it will combine them into one row. There are different ways this can be done - basically you can choose whether to use any value from either dataframe (how="outer") only values found in both dataframes (how="inner") only values in the first dataframe (how="left") or in the second (how="right").

# %%
ge1.merge(ge2,on="Gene",how='outer')
# Out:
#            Gene  Expression_x  Expression_y
# 0      15S_rRNA            29             5
# 1      21S_rRNA           221            23
# 2          HRA1             0             3
# 3          ICR1            70           211
# 4          LSR1           314           159
# ...         ...           ...           ...
# 7121  tY(GUA)J2             0             0
# 7122  tY(GUA)M1             0             1
# 7123  tY(GUA)M2             0             0
# 7124   tY(GUA)O             0             0
# 7125   tY(GUA)Q             0             0
#
# [7126 rows x 3 columns]

# %% [markdown]
# The nice thing about merge is that it doesn't care what order the data are in. We can show this by sorting ge1 and ge2 on in different ways and remerge.

# %%
ge1 = ge1.sort_values('Expression')
ge2 = ge2.sort_values('Gene')

# %%
ge1.merge(ge2,on="Gene",how='outer').sort_values('Gene')
# Out:
#            Gene  Expression_x  Expression_y
# 1549   15S_rRNA            29             5
# 3614   21S_rRNA           221            23
# 216        HRA1             0             3
# 1985       ICR1            70           211
# 4389       LSR1           314           159
# ...         ...           ...           ...
# 186   tY(GUA)J2             0             0
# 172   tY(GUA)M1             0             1
# 217   tY(GUA)M2             0             0
# 144    tY(GUA)O             0             0
# 0      tY(GUA)Q             0             0
#
# [7126 rows x 3 columns]

# %% [markdown]
# How do we do this for 96 files?
#
# First, let's get a list of all the files. To do this we use the

# %%
os.listdir('data/rawdata')
# Out:
# ['Snf2_rep39_MID19_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep18_MID48_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep17_MID66_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep31_MID77_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep43_MID73_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep35_MID60_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep28_MID74_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep08_MID78_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep30_MID16_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep08_MID20_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep40_MID12_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep40_MID18_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep28_MID64_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep06_MID30_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep14_MID33_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep03_MID51_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep01_MID96_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep31_MID43_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep42_MID10_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep30_MID27_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep48_MID55_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep20_MID90_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep03_MID28_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep48_MID85_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep38_MID06_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep15_MID75_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep38_MID87_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep45_MID86_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep45_MID44_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep15_MID09_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep34_MID76_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep19_MID84_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep07_MID24_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep33_MID88_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep41_MID13_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep05_MID82_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep43_MID49_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep13_MID59_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep27_MID41_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep19_MID83_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep10_MID37_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep07_MID26_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep36_MID23_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep10_MID38_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep46_MID35_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep35_MID32_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep20_MID15_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep26_MID08_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep12_MID02_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep47_MID17_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep16_MID92_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep24_MID42_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep27_MID34_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep41_MID79_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep21_MID31_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep09_MID04_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep24_MID69_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep26_MID71_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep09_MID91_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep13_MID45_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep23_MID36_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep37_MID46_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep14_MID52_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep32_MID70_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep05_MID93_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep42_MID47_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep04_MID11_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep29_MID57_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep25_MID61_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep18_MID40_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep34_MID14_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep39_MID05_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep11_MID54_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep02_MID21_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep29_MID68_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep01_MID39_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep04_MID58_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep21_MID62_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep12_MID03_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep25_MID81_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep47_MID56_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep22_MID67_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep46_MID94_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep44_MID65_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep32_MID95_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep22_MID53_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep16_MID72_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep17_MID89_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep11_MID01_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep23_MID25_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep06_MID80_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep33_MID29_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep44_MID22_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep02_MID50_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep37_MID07_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep36_MID63_allLanes_tophat2.0.5.bam.gbgout']

# %% [markdown]
# Would be nicer if this were sorted

# %%
sorted(os.listdir('data/rawdata'))
# Out:
# ['Snf2_rep01_MID96_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep02_MID21_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep03_MID28_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep04_MID11_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep05_MID82_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep06_MID80_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep07_MID26_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep08_MID78_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep09_MID04_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep10_MID38_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep11_MID01_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep12_MID02_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep13_MID59_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep14_MID33_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep15_MID75_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep16_MID72_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep17_MID89_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep18_MID40_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep19_MID84_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep20_MID15_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep21_MID31_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep22_MID53_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep23_MID25_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep24_MID42_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep25_MID81_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep26_MID71_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep27_MID34_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep28_MID74_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep29_MID57_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep30_MID16_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep31_MID77_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep32_MID70_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep33_MID29_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep34_MID14_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep35_MID60_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep36_MID23_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep37_MID46_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep38_MID06_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep39_MID19_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep40_MID12_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep41_MID79_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep42_MID47_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep43_MID73_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep44_MID65_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep45_MID86_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep46_MID35_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep47_MID56_allLanes_tophat2.0.5.bam.gbgout',
#  'Snf2_rep48_MID55_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep01_MID39_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep02_MID50_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep03_MID51_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep04_MID58_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep05_MID93_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep06_MID30_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep07_MID24_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep08_MID20_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep09_MID91_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep10_MID37_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep11_MID54_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep12_MID03_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep13_MID45_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep14_MID52_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep15_MID09_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep16_MID92_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep17_MID66_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep18_MID48_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep19_MID83_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep20_MID90_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep21_MID62_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep22_MID67_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep23_MID36_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep24_MID69_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep25_MID61_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep26_MID08_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep27_MID41_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep28_MID64_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep29_MID68_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep30_MID27_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep31_MID43_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep32_MID95_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep33_MID88_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep34_MID76_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep35_MID32_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep36_MID63_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep37_MID07_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep38_MID87_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep39_MID05_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep40_MID18_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep41_MID13_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep42_MID10_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep43_MID49_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep44_MID22_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep45_MID44_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep46_MID94_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep47_MID17_allLanes_tophat2.0.5.bam.gbgout',
#  'WT_rep48_MID85_allLanes_tophat2.0.5.bam.gbgout']

# %% [markdown]
# The files contain information about the experiment, which we want to extract. We'll do this using the 'split' command, which takes a string and splits it up based on some character in the string. Here we care about the first two parts of the file name, whether it's WT or mutant, and which replicate it is.
#
# Let's illustrate what we're going to do with an example.

# %%
filename = 'WT_rep25_MID61_allLanes_tophat2.0.5.bam.gbgout'

# %% [markdown]
# We want to split the string using the '_' character.

# %%
filename.split('_')
# Out:
# ['WT', 'rep25', 'MID61', 'allLanes', 'tophat2.0.5.bam.gbgout']

# %%
filesplit = filename.split('_')
exp_type = filesplit[0]
rep = filesplit[1]

print ('Exp type: ' + exp_type)
print ('Rep: ' + rep)
# Out:
# Exp type: WT
# Rep: rep25

# %%
# get a list of files

files = [f for f in sorted(os.listdir('data/rawdata')) if f.endswith(".gbgout")]

# start with first file

file = files[0]
filesplit = file.split('_')
exp_type = filesplit[0]
rep = filesplit[1]

exp_id = exp_type + "_" + rep

filepath = os.path.join('data/rawdata/', file)

# rather than using Gene, Expression we change the columns to Gene, Experiment ID
expression_all = pd.read_csv(filepath, sep="\t", header = None, names=['Gene',exp_id])

# now loop over remainder of files and merge to data frame

for file in files[1:]:
    print (file)
    filesplit = file.split('_')
    exp_type = filesplit[0]
    rep = filesplit[1]
    exp_id = exp_type + "_" + rep
    filepath = os.path.join('data/rawdata/', file)
    
    expression_all = expression_all.merge(pd.read_csv(filepath, sep="\t", header = None, names=['Gene',exp_id]), on="Gene", how="outer")
# Out:
# Snf2_rep02_MID21_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep03_MID28_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep04_MID11_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep05_MID82_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep06_MID80_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep07_MID26_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep08_MID78_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep09_MID04_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep10_MID38_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep11_MID01_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep12_MID02_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep13_MID59_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep14_MID33_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep15_MID75_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep16_MID72_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep17_MID89_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep18_MID40_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep19_MID84_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep20_MID15_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep21_MID31_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep22_MID53_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep23_MID25_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep24_MID42_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep25_MID81_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep26_MID71_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep27_MID34_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep28_MID74_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep29_MID57_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep30_MID16_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep31_MID77_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep32_MID70_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep33_MID29_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep34_MID14_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep35_MID60_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep36_MID23_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep37_MID46_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep38_MID06_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep39_MID19_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep40_MID12_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep41_MID79_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep42_MID47_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep43_MID73_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep44_MID65_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep45_MID86_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep46_MID35_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep47_MID56_allLanes_tophat2.0.5.bam.gbgout
# Snf2_rep48_MID55_allLanes_tophat2.0.5.bam.gbgout
# WT_rep01_MID39_allLanes_tophat2.0.5.bam.gbgout
# WT_rep02_MID50_allLanes_tophat2.0.5.bam.gbgout
# WT_rep03_MID51_allLanes_tophat2.0.5.bam.gbgout
# WT_rep04_MID58_allLanes_tophat2.0.5.bam.gbgout
# WT_rep05_MID93_allLanes_tophat2.0.5.bam.gbgout
# WT_rep06_MID30_allLanes_tophat2.0.5.bam.gbgout
# WT_rep07_MID24_allLanes_tophat2.0.5.bam.gbgout
# WT_rep08_MID20_allLanes_tophat2.0.5.bam.gbgout
# WT_rep09_MID91_allLanes_tophat2.0.5.bam.gbgout
# WT_rep10_MID37_allLanes_tophat2.0.5.bam.gbgout
# WT_rep11_MID54_allLanes_tophat2.0.5.bam.gbgout
# WT_rep12_MID03_allLanes_tophat2.0.5.bam.gbgout
# WT_rep13_MID45_allLanes_tophat2.0.5.bam.gbgout
# WT_rep14_MID52_allLanes_tophat2.0.5.bam.gbgout
# WT_rep15_MID09_allLanes_tophat2.0.5.bam.gbgout
# WT_rep16_MID92_allLanes_tophat2.0.5.bam.gbgout
# WT_rep17_MID66_allLanes_tophat2.0.5.bam.gbgout
# WT_rep18_MID48_allLanes_tophat2.0.5.bam.gbgout
# WT_rep19_MID83_allLanes_tophat2.0.5.bam.gbgout
# WT_rep20_MID90_allLanes_tophat2.0.5.bam.gbgout
# WT_rep21_MID62_allLanes_tophat2.0.5.bam.gbgout
# WT_rep22_MID67_allLanes_tophat2.0.5.bam.gbgout
# WT_rep23_MID36_allLanes_tophat2.0.5.bam.gbgout
# WT_rep24_MID69_allLanes_tophat2.0.5.bam.gbgout
# WT_rep25_MID61_allLanes_tophat2.0.5.bam.gbgout
# WT_rep26_MID08_allLanes_tophat2.0.5.bam.gbgout
# WT_rep27_MID41_allLanes_tophat2.0.5.bam.gbgout
# WT_rep28_MID64_allLanes_tophat2.0.5.bam.gbgout
# WT_rep29_MID68_allLanes_tophat2.0.5.bam.gbgout
# WT_rep30_MID27_allLanes_tophat2.0.5.bam.gbgout
# WT_rep31_MID43_allLanes_tophat2.0.5.bam.gbgout
# WT_rep32_MID95_allLanes_tophat2.0.5.bam.gbgout
# WT_rep33_MID88_allLanes_tophat2.0.5.bam.gbgout
# WT_rep34_MID76_allLanes_tophat2.0.5.bam.gbgout
# WT_rep35_MID32_allLanes_tophat2.0.5.bam.gbgout
# WT_rep36_MID63_allLanes_tophat2.0.5.bam.gbgout
# WT_rep37_MID07_allLanes_tophat2.0.5.bam.gbgout
# WT_rep38_MID87_allLanes_tophat2.0.5.bam.gbgout
# WT_rep39_MID05_allLanes_tophat2.0.5.bam.gbgout
# WT_rep40_MID18_allLanes_tophat2.0.5.bam.gbgout
# WT_rep41_MID13_allLanes_tophat2.0.5.bam.gbgout
# WT_rep42_MID10_allLanes_tophat2.0.5.bam.gbgout
# WT_rep43_MID49_allLanes_tophat2.0.5.bam.gbgout
# WT_rep44_MID22_allLanes_tophat2.0.5.bam.gbgout
# WT_rep45_MID44_allLanes_tophat2.0.5.bam.gbgout
# WT_rep46_MID94_allLanes_tophat2.0.5.bam.gbgout
# WT_rep47_MID17_allLanes_tophat2.0.5.bam.gbgout
# WT_rep48_MID85_allLanes_tophat2.0.5.bam.gbgout

# %%
expression_all
# Out:
#                       Gene  Snf2_rep01  Snf2_rep02  Snf2_rep03  Snf2_rep04  \
# 0                 15S_rRNA           4           2           5           5
# 1                 21S_rRNA          31          18          23          44
# 2                     HRA1           5           1           3           1
# 3                     ICR1         205         196         211         252
# 4                     LSR1         210         103         159         260
# ...                    ...         ...         ...         ...         ...
# 7126            no_feature      888995      641333      544060      955003
# 7127             ambiguous      730793      665470      709428      821933
# 7128         too_low_aQual           0           0           0           0
# 7129           not_aligned           0           0           0           0
# 7130  alignment_not_unique           0           0           0           0
#
#       Snf2_rep05  Snf2_rep06  Snf2_rep07  Snf2_rep08  Snf2_rep09  ...  \
# 0             46           3           5           4           2  ...
# 1            356          62          35          33          13  ...
# 2              2           1           1           4           4  ...
# 3            127         146         275         160         190  ...
# 4            298         522         303          96         132  ...
# ...          ...         ...         ...         ...         ...  ...
# 7126      616339      764571     1290592      598769      827934  ...
# 7127     1171511      529946      925353      669715      717502  ...
# 7128           0           0           0           0           0  ...
# 7129           0           0           0           0           0  ...
# 7130           0           0           0           0           0  ...
#
#       WT_rep39  WT_rep40  WT_rep41  WT_rep42  WT_rep43  WT_rep44  WT_rep45  \
# 0            0        49         9         4        11        12         1
# 1           10       274        49        30        72        58        21
# 2            5         3         6         5         2         2         2
# 3           85       177       137       118       113        81       142
# 4           66       385       232       149       114        81       109
# ...        ...       ...       ...       ...       ...       ...       ...
# 7126    403527   1035268    759722    578053    615809    446796    683906
# 7127    583744   2002465    865662    646805    570375   1011281    899586
# 7128         0         0         0         0         0         0         0
# 7129         0         0         0         0         0         0         0
# 7130         0         0         0         0         0         0         0
#
#       WT_rep46  WT_rep47  WT_rep48
# 0           22        12         4
# 1          159       107        70
# 2            5         2         1
# 3           94       187       106
# 4          132       243       128
# ...        ...       ...       ...
# 7126    462390    901045    639100
# 7127    596335   1321941    803015
# 7128         0         0         0
# 7129         0         0         0
# 7130         0         0         0
#
# [7131 rows x 97 columns]

# %% [markdown]
# The files are incredible simple. Two columns, separated by tabs. The first column is the gene name, the second column the normalized counts for that gene in that sample (read the paper if you're interested in how they did the counting and normalization).
#
# YBL013W 39 YBL014C 127 YBL015W 732 YBL016W 309 YBL017C 1613 YBL018C 174 YBL019W 117 YBL020W 258 YBL021C 248 YBL022C 1168 YBL023C 331 YBL024W 451 YBL025W 64 YBL026W 206 YBL027W 9723 YBL028C 77 YBL029C-A 157

# %%
expression_all = expression_all[~expression_all.Gene.isin(rows_to_drop)]

# %%
expression_all
# Out:
#            Gene  Snf2_rep01  Snf2_rep02  Snf2_rep03  Snf2_rep04  Snf2_rep05  \
# 0      15S_rRNA           4           2           5           5          46
# 1      21S_rRNA          31          18          23          44         356
# 2          HRA1           5           1           3           1           2
# 3          ICR1         205         196         211         252         127
# 4          LSR1         210         103         159         260         298
# ...         ...         ...         ...         ...         ...         ...
# 7121  tY(GUA)J2           1           0           0           0           0
# 7122  tY(GUA)M1           0           0           1           0           2
# 7123  tY(GUA)M2           0           0           0           0           0
# 7124   tY(GUA)O           0           1           0           0           0
# 7125   tY(GUA)Q           0           0           0           0           0
#
#       Snf2_rep06  Snf2_rep07  Snf2_rep08  Snf2_rep09  ...  WT_rep39  WT_rep40  \
# 0              3           5           4           2  ...         0        49
# 1             62          35          33          13  ...        10       274
# 2              1           1           4           4  ...         5         3
# 3            146         275         160         190  ...        85       177
# 4            522         303          96         132  ...        66       385
# ...          ...         ...         ...         ...  ...       ...       ...
# 7121           0           0           1           0  ...         0         0
# 7122           0           0           0           0  ...         0         1
# 7123           0           0           0           0  ...         0         0
# 7124           0           0           0           0  ...         0         0
# 7125           0           0           0           0  ...         0         0
#
#       WT_rep41  WT_rep42  WT_rep43  WT_rep44  WT_rep45  WT_rep46  WT_rep47  \
# 0            9         4        11        12         1        22        12
# 1           49        30        72        58        21       159       107
# 2            6         5         2         2         2         5         2
# 3          137       118       113        81       142        94       187
# 4          232       149       114        81       109       132       243
# ...        ...       ...       ...       ...       ...       ...       ...
# 7121         0         0         0         0         0         0         0
# 7122         1         0         1         0         0         0         1
# 7123         0         0         0         0         0         0         0
# 7124         1         0         0         0         0         0         0
# 7125         0         0         0         0         0         0         0
#
#       WT_rep48
# 0            4
# 1           70
# 2            1
# 3          106
# 4          128
# ...        ...
# 7121         0
# 7122         0
# 7123         0
# 7124         1
# 7125         0
#
# [7126 rows x 97 columns]

# %%
# Save

expression_all.to_csv("Barton_combined.txt", sep='\t')
